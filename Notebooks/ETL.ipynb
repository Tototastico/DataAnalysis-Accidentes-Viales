# %% [markdown]
# ## ETL

# %%
import pandas as pd
import re
import datetime
import numpy as np

# %% [markdown]
# Extraccion

# %%
# Extraemos los datos de las horas que necesitamos
hechos = pd.read_excel('../Data/homicidios.xlsx', sheet_name='HECHOS')
victimas = pd.read_excel('../Data/homicidios.xlsx', sheet_name='VICTIMAS')

# %% [markdown]
# ## Comenzamos con el dataset de hechos.

# %%
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  696 non-null    object
#  17  pos y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                696 non-null    object
#  20  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 114.3+ KB

# %% [markdown]
# Tiene pocos registros nulos, pero si tiene columnas con muchos nulos

# %%
# Vemos como estan conformados los registros
hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS
#
# [5 rows x 21 columns]

# %%
# Aca vemos que hay cruces donde ocurren mas accidentes
hechos.Cruce.value_counts()
# Out:
# Cruce
# PAZ, GRAL. AV.              14
# ESCALADA AV.                 9
# RIVADAVIA AV.                8
# INDEPENDENCIA AV.            7
# BALBIN, RICARDO, DR. AV.     6
#                             ..
# LA RIOJA                     1
# TRAFUL                       1
# HUMAITA                      1
# MANZANARES                   1
# HUGO, VICTOR                 1
# Name: count, Length: 317, dtype: int64

# %%
# Capitalizamos todas las columnas
hechos.columns = hechos.columns.str.capitalize()

# %%
# Vemos la cantidad de columnas que tenemos
hechos.columns.tolist()
# Out:
# ['Id',
#  'N_victimas',
#  'Fecha',
#  'Aaaa',
#  'Mm',
#  'Dd',
#  'Hora',
#  'Hh',
#  'Lugar_del_hecho',
#  'Tipo_de_calle',
#  'Calle',
#  'Altura',
#  'Cruce',
#  'Dirección normalizada',
#  'Comuna',
#  'Xy (caba)',
#  'Pos x',
#  'Pos y',
#  'Participantes',
#  'Victima',
#  'Acusado']

# %% [markdown]
# Ahora procedemos a analizar las fechas

# %%
fechas_correctas = [] # Instanciamos una lista vacia de fechas correctas
fechas_incorrectas = [] # Instanciamos una lista vacia de fechas incorrectas

for fecha in hechos.Fecha.unique().tolist(): # Recorremos las fechas de la columna fecha
    fecha = str(fecha) # Transformamos a string
    try:
        # Intenta analizar la fecha
        datetime.datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S') # Si la fecha tiene el formato correcto
        fechas_correctas.append(fecha) # La agregamos a las fechas correctas
    except ValueError:
        fechas_incorrectas.append(fecha) # Si tiene el formato incorrecto, evade el error y suma a incorrectas

# Imprimimos los resultados

print("Fechas correctas:") 
for fecha in fechas_correctas:
    print(fecha)

print("\nFechas incorrectas:")
for fecha in fechas_incorrectas:
    print(fecha)
# Out:
# Fechas correctas:
# 2016-01-01 00:00:00
# 2016-01-02 00:00:00
# 2016-01-03 00:00:00
# 2016-01-10 00:00:00
# 2016-01-21 00:00:00
# 2016-01-24 00:00:00
# 2016-01-29 00:00:00
# 2016-02-08 00:00:00
# 2016-02-10 00:00:00
# 2016-02-14 00:00:00
# 2016-02-15 00:00:00
# 2016-02-17 00:00:00
# 2016-02-21 00:00:00
# 2016-02-28 00:00:00
# 2016-03-02 00:00:00
# 2016-03-04 00:00:00
# 2016-03-08 00:00:00
# 2016-03-12 00:00:00
# 2016-03-13 00:00:00
# 2016-03-14 00:00:00
# 2021-05-26 00:00:00
# 2021-05-31 00:00:00
# 2021-06-02 00:00:00
# 2021-06-03 00:00:00
# 2021-06-10 00:00:00
# 2021-06-15 00:00:00
# 2021-06-20 00:00:00
# 2021-06-22 00:00:00
# 2021-06-29 00:00:00
# 2021-07-09 00:00:00
# 2021-07-10 00:00:00
# 2021-07-21 00:00:00
# 2021-07-22 00:00:00
# 2021-07-24 00:00:00
# 2021-07-27 00:00:00
# 2021-08-02 00:00:00
# 2021-08-06 00:00:00
# 2021-08-08 00:00:00
# 2021-08-15 00:00:00
# 2021-08-20 00:00:00
# 2021-08-28 00:00:00
# 2021-08-31 00:00:00
# 2021-09-01 00:00:00
# 2021-09-18 00:00:00
# 2021-09-20 00:00:00
# 2021-09-21 00:00:00
# 2021-10-16 00:00:00
# 2021-10-18 00:00:00
# 2021-10-23 00:00:00
# 2021-10-25 00:00:00
# 2021-10-28 00:00:00
# 2021-11-02 00:00:00
# 2021-11-06 00:00:00
# 2021-11-09 00:00:00
# 2021-11-11 00:00:00
# 2021-11-20 00:00:00
# 2021-11-25 00:00:00
# 2021-11-27 00:00:00
# 2021-12-01 00:00:00
# 2021-12-02 00:00:00
# 2021-12-10 00:00:00
# 2021-12-11 00:00:00
# 2021-12-12 00:00:00
# 2021-12-13 00:00:00
# 2021-12-20 00:00:00
# 2021-12-30 00:00:00
# 2021-12-15 00:00:00
# 2021-11-18 00:00:00
#
# Fechas incorrectas:

# %% [markdown]
# Este analisis nos dice que no tenemos ninguna fecha incorrecta asi que podemos eliminar las columnas de 'Aaaa','Mm' y 'Dd'

# %%
cols_a_eliminar = [
    'Xy (caba)', # Eliminamos esta columna ya que tenemos las coordenadas en otras columnas
    'Aaaa',
    'Mm',
    'Dd',
    'Calle', # La calle la tenemos en la direccion normalizada
    'Altura', # La altura la tenemos en la direccion normalizada
    'Participantes' # Eliminamos los participantes porque los tenemos en victimas y acusados
]

hechos = hechos.drop(columns=cols_a_eliminar) # Eliminamos las columnas

# %% [markdown]
# Elijo cuales capitalizar y cuales minusculizar, dependiendo del dato.

# %%
a_cap = ['Cruce','Dirección normalizada', 'Lugar_del_hecho'] # A capitalizar
a_min = ['Tipo_de_calle','Victima', 'Acusado'] # A minuscula

# %%
for columna in a_cap:
    hechos[columna] = hechos[columna].str.capitalize()

# Hacemos las capidalizaciones y las minusculas

for columna in a_min:
    hechos[columna] = hechos[columna].str.lower()

# %%
# LLeno las direcciones normalizadas nulas con su respectivo dato de Lugar_del_hecho
hechos['Dirección normalizada'] = hechos['Dirección normalizada'].fillna(hechos['Lugar_del_hecho'])
hechos.drop('Lugar_del_hecho',axis=1, inplace=True) # Elimino la columna Lugar_del_hecho

# %%
hechos.rename(columns={'Dirección normalizada':'Lugar_del_hecho'}, inplace=True) # Renombro la columna a gusto

# %%
hechos['Hora'] = hechos['Hora'].apply(lambda x: str(x)[:2]) # Creo la columna hora con la hora del suceso
hechos.drop('Hh',axis=1, inplace=True) # Y elimino 'Hh'

# %%
for col in ['N_victimas','Tipo_de_calle', 'Comuna', 'Victima', 'Acusado']:
    print(hechos[col].unique().tolist()) # Visualizo los valore unicos por columna
# Out:
# [1, 2, 3]
# ['avenida', 'gral paz', 'calle', 'autopista']
# [8, 9, 1, 11, 15, 4, 7, 12, 3, 13, 14, 10, 6, 2, 5, 0]
# ['moto', 'auto', 'peaton', 'sd', 'cargas', 'bicicleta', 'pasajeros', 'movil', 'objeto fijo', 'peaton_moto']
# ['auto', 'pasajeros', 'sd', 'objeto fijo', 'cargas', 'moto', 'multiple', 'otro', 'bicicleta', 'tren']

# %% [markdown]
# Vemos que tenemos ciertos registros 'SD' o, sin dato, asi que los imputamos

# %%
hechos.loc[hechos['Hora'] == 'SD', 'Hora'] = '00' # Las horas sin dato las imputo como las 00hs
hechos.Hora = hechos.Hora.astype(int) # Transformo la columna a enteros

# %% [markdown]
# Imputo los sindato a nan

# %%
def sd_to_null(text): # Creamos la funcion
    if type(text) == str: # Si el dato es de tipo string
        if text.lower() == 'sd': # Entonces lo pasamos a minuscula para contener [Sd, SD o sD]
            return np.nan # Y si es sin dato, lo cambiamos a nulo
        else:
            return text # Sino, retornamos el texto
    return text # Sino, retornamos el texto

# %%
for col in hechos.columns.tolist():
    hechos[col]=hechos[col].apply(lambda x: sd_to_null(x)) # Aplicamos a cada columna

# %% [markdown]
# Listo, nulos y sin datos, tratados

# %%
hechos[hechos['Pos x'] == '.'].count() # Las latitudes y longitudes tienen puntos en vez de nulos
# Out:
# Id                 12
# N_victimas         12
# Fecha              12
# Hora               12
# Tipo_de_calle      12
# Cruce               0
# Lugar_del_hecho    11
# Comuna             12
# Pos x              12
# Pos y              12
# Victima            11
# Acusado             9
# dtype: int64

# %%
hechos[hechos['Pos y'] == '.'].count()
# Out:
# Id                 12
# N_victimas         12
# Fecha              12
# Hora               12
# Tipo_de_calle      12
# Cruce               0
# Lugar_del_hecho    11
# Comuna             12
# Pos x              12
# Pos y              12
# Victima            11
# Acusado             9
# dtype: int64

# %% [markdown]
# Tenemos solo 12 registros, pero no logro imputarlos, ya que por ejemplo, Autopista lugones pk 10000, en el maps no permite buscar por kilometro en esa autopista.

# %%
hechos[(hechos['Pos y'] == '.') & (hechos['Pos x'] == '.')][['Pos y','Pos x']] # Mostramos los registros
# Out:
#     Pos y Pos x
# 38      .     .
# 106     .     .
# 119     .     .
# 139     .     .
# 176     .     .
# 180     .     .
# 181     .     .
# 256     .     .
# 313     .     .
# 546     .     .
# 559     .     .
# 621     .     .

# %%
hechos.loc[hechos['Pos y'] == '.', 'Pos y'] = np.nan # Transformo los puntos a nulos en ambas columnas
hechos.loc[hechos['Pos x'] == '.', 'Pos x'] = np.nan

# %%
hechos['Pos x'] = hechos['Pos x'].astype(float) # Y ahora los registros a flotantes
hechos['Pos y'] = hechos['Pos y'].astype(float) # Y ahora los registros a flotantes

# %% [markdown]
# Renombre de columnas

# %%
# Renombro las columnas para una mejor comprension
hechos.rename(columns={'Id':'Id_hecho',
 'N_victimas':'Victimas',
 'Fecha':'Fecha',
 'Hora':'Hora',
 'Tipo_de_calle':'Tipo_calle',
 'Cruce':'Cruce',
 'Lugar_del_hecho':'Direccion',
 'Comuna':'Comuna',
 'Pos x': 'Longitud',
 'Pos y': 'Latitud',
 'Victima':'Tipo_victima',
 'Acusado':'Tipo_acusado'}, inplace=True)

# %% [markdown]
# Analisis de valores repetidos

# %%
for col in hechos.columns.tolist():
    print(col,":",hechos[col].duplicated().unique()) # Vemos los unicos
# Out:
# Id_hecho : [False]
# Victimas : [False  True]
# Fecha : [False  True]
# Hora : [False  True]
# Tipo_calle : [False  True]
# Cruce : [False  True]
# Direccion : [False  True]
# Comuna : [False  True]
# Longitud : [False  True]
# Latitud : [False  True]
# Tipo_victima : [False  True]
# Tipo_acusado : [False  True]

# %% [markdown]
# Vemos que tenemos duplicados en casi todas las columnas, vamos a analizarlos

# %%
hechos[hechos[['Longitud','Latitud']].duplicated()][['Longitud','Latitud']]
# Out:
#       Longitud    Latitud
# 7   -58.508775 -34.669777
# 37  -58.406239 -34.650765
# 68  -58.467435 -34.534769
# 89  -58.444513 -34.684759
# 106        NaN        NaN
# ..         ...        ...
# 670 -58.393039 -34.598711
# 672 -58.500738 -34.549795
# 676 -58.427797 -34.622073
# 690 -58.405969 -34.610120
# 692 -58.467398 -34.651178
#
# [91 rows x 2 columns]

# %% [markdown]
# Primero vemos que las coordenadas no estan realmente duplicadas, la funcion duplicated() las toma como duplicadas xq varian por decimales muy chicos.

# %%
hechos[hechos['Direccion'].duplicated()].head()
# Out:
#       Id_hecho  Victimas      Fecha  Hora Tipo_calle                    Cruce  \
# 7    2016-0010         1 2016-01-29    15   gral paz      De los corrales av.
# 37   2016-0051         1 2016-04-20     4    avenida  Bonavena, oscar natalio
# 68   2016-0092         1 2016-07-15    11   gral paz       Del libertador av.
# 89   2016-0116         1 2016-09-02    20    avenida             Escalada av.
# 112  2016-0143         1 2016-11-06     4    avenida             Escalada av.
#
#                                           Direccion  Comuna   Longitud  \
# 7              Paz, gral. av. y de los corrales av.       9 -58.508775
# 37   Alcorta, amancio av. y bonavena, oscar natalio       4 -58.406239
# 68              Paz, gral. av. y del libertador av.      13 -58.467435
# 89                 27 de febrero av. y escalada av.       8 -58.444513
# 112                27 de febrero av. y escalada av.       8 -58.444513
#
#        Latitud Tipo_victima Tipo_acusado
# 7   -34.669777         moto         auto
# 37  -34.650765         moto       cargas
# 68  -34.534769         moto       cargas
# 89  -34.684759         moto         auto
# 112 -34.684759         moto          NaN

# %% [markdown]
# Vemos que pese a q haya direcciones y cruces duplicadas, es porque se ve que en esas direcciones o cruces suceden siniestros mas frecuentemente. Realmente no es un error que haya duplicados

# %% [markdown]
# ## Ahora trabajamos con las victimas

# %%
victimas.info() # Veamos su informacion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  717 non-null    object
#  6   VICTIMA              717 non-null    object
#  7   SEXO                 717 non-null    object
#  8   EDAD                 717 non-null    object
#  9   FECHA_FALLECIMIENTO  717 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 56.1+ KB

# %% [markdown]
# De primeras, no tenemos ningun nulo.

# %%
victimas.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %%
victimas.columns = victimas.columns.str.capitalize() # Capitalizo todas las columnas

# %% [markdown]
# Hago el mismo analisis anterior de fechas para ambas columnas

# %%
# Para 'Fecha'
fechas_correctas = []
fechas_incorrectas = []

for fecha in victimas.Fecha.unique().tolist():
    fecha = str(fecha)
    try:
        # Intenta analizar la fecha
        datetime.datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S')
        fechas_correctas.append(fecha)
    except ValueError:
        # Captura las excepciones ValueError (formato incorrecto)
        fechas_incorrectas.append(fecha)

print("Fechas correctas:")
for fecha in fechas_correctas:
    print(fecha)

print("\nFechas incorrectas:")
for fecha in fechas_incorrectas:
    print(fecha)
# Out:
# Fechas correctas:
# 2016-01-01 00:00:00
# 2016-01-02 00:00:00
# 2016-01-03 00:00:00
# 2016-01-10 00:00:00
# 2016-01-21 00:00:00
# 2016-01-24 00:00:00
# 2016-01-29 00:00:00
# 2016-02-08 00:00:00
# 2016-02-10 00:00:00
# 2016-02-14 00:00:00
# 2016-02-15 00:00:00
# 2016-02-17 00:00:00
# 2016-02-21 00:00:00
# 2016-02-28 00:00:00
# 2016-03-02 00:00:00
# 2016-03-04 00:00:00
# 2016-03-08 00:00:00
# 2016-03-12 00:00:00
# 2016-03-13 00:00:00
# 2016-03-14 00:00:00
# 2016-03-19 00:00:00
# 2016-03-21 00:00:00
# 2016-03-23 00:00:00
# 2016-03-29 00:00:00
# 2016-03-30 00:00:00
# 2016-03-31 00:00:00
# 2016-04-11 00:00:00
# 2016-04-15 00:00:00
# 2016-04-17 00:00:00
# 2016-04-19 00:00:00
# 2016-04-20 00:00:00
# 2016-04-22 00:00:00
# 2016-04-23 00:00:00
# 2016-04-25 00:00:00
# 2016-04-26 00:00:00
# 2016-05-04 00:00:00
# 2016-05-08 00:00:00
# 2016-05-14 00:00:00
# 2016-05-20 00:00:00
# 2016-05-21 00:00:00
# 2016-05-22 00:00:00
# 2016-05-23 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-16 00:00:00
# 2016-06-18 00:00:00
# 2016-06-22 00:00:00
# 2016-06-27 00:00:00
# 2021-01-31 00:00:00
# 2021-02-18 00:00:00
# 2021-02-06 00:00:00
# 2021-02-14 00:00:00
# 2021-02-17 00:00:00
# 2021-03-08 00:00:00
# 2021-02-21 00:00:00
# 2021-03-04 00:00:00
# 2021-03-06 00:00:00
# 2021-03-01 00:00:00
# 2021-03-03 00:00:00
# 2021-03-11 00:00:00
# 2021-03-15 00:00:00
# 2021-03-16 00:00:00
# 2021-03-29 00:00:00
# 2021-04-02 00:00:00
# 2021-04-07 00:00:00
# 2021-04-11 00:00:00
# 2021-04-29 00:00:00
# 2021-04-14 00:00:00
# 2021-04-19 00:00:00
# 2021-05-03 00:00:00
# 2021-05-09 00:00:00
# 2021-05-11 00:00:00
# 2021-05-14 00:00:00
# 2021-06-05 00:00:00
# 2021-05-20 00:00:00
# 2021-05-21 00:00:00
# 2021-05-22 00:00:00
# 2021-05-25 00:00:00
# 2021-05-26 00:00:00
# 2021-05-31 00:00:00
# 2021-06-02 00:00:00
# 2021-06-23 00:00:00
# 2021-06-03 00:00:00
# 2021-06-10 00:00:00
# 2021-06-16 00:00:00
# 2021-06-20 00:00:00
# 2021-06-30 00:00:00
# 2021-06-22 00:00:00
# 2021-06-29 00:00:00
# 2021-07-09 00:00:00
# 2021-07-10 00:00:00
# 2021-07-21 00:00:00
# 2021-07-22 00:00:00
# 2021-07-24 00:00:00
# 2021-07-27 00:00:00
# 2021-08-02 00:00:00
# 2021-08-03 00:00:00
# 2021-08-10 00:00:00
# 2021-08-09 00:00:00
# 2021-08-08 00:00:00
# 2021-08-15 00:00:00
# 2021-08-21 00:00:00
# 2021-08-28 00:00:00
# 2021-09-01 00:00:00
# 2021-09-18 00:00:00
# 2021-09-20 00:00:00
# 2021-09-21 00:00:00
# 2021-10-16 00:00:00
# 2021-10-18 00:00:00
# 2021-10-23 00:00:00
# 2021-10-25 00:00:00
# 2021-10-28 00:00:00
# 2021-11-02 00:00:00
# 2021-11-06 00:00:00
# 2021-11-09 00:00:00
# 2021-11-11 00:00:00
# 2021-11-19 00:00:00
# 2021-11-20 00:00:00
# 2021-11-25 00:00:00
# 2021-11-27 00:00:00
# 2021-12-07 00:00:00
# 2021-12-11 00:00:00
# 2022-01-03 00:00:00
# 2021-12-12 00:00:00
# 2021-12-18 00:00:00
# 2021-12-20 00:00:00
# 2022-01-02 00:00:00
#
# Fechas incorrectas:
# SD
# 26/03/2019

# %% [markdown]
# Vemos que tenemos solo una fecha incorrecta asi que la imputamos manualmente.

# %%
victimas.loc[victimas['Fecha_fallecimiento'] == '26/03/2019', 'Fecha_fallecimiento'] = datetime.datetime.strptime('26/03/2019', '%d/%m/%Y')

# %%
cols_a_eliminar = [
    'Aaaa',
    'Mm',
    'Dd',
] # Eliminamos estas columnas ya que tenemos las fechas correctas

victimas = victimas.drop(columns=cols_a_eliminar)

# %%
a_min = ['Rol', 'Victima', 'Sexo'] # Elegimos las columnas a pasar a minusculas

# %%
for columna in a_min:
    victimas[columna] = victimas[columna].str.lower() # Las pasamos a minusculas

# %%
victimas.head() # Vemos como esta conformado nuestro dataset parcialmente limpio
# Out:
#     Id_hecho      Fecha        Rol Victima       Sexo Edad  \
# 0  2016-0001 2016-01-01  conductor    moto  masculino   19
# 1  2016-0002 2016-01-02  conductor    auto  masculino   70
# 2  2016-0003 2016-01-03  conductor    moto  masculino   30
# 3  2016-0004 2016-01-10  conductor    moto  masculino   18
# 4  2016-0005 2016-01-21  conductor    moto  masculino   29
#
#    Fecha_fallecimiento
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %%
for col in victimas.columns.tolist():
    victimas[col]=victimas[col].apply(lambda x: sd_to_null(x)) # Aplicamos la funcion de los sin dato anterior

# %%
victimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id_hecho             717 non-null    object
#  1   Fecha                717 non-null    datetime64[ns]
#  2   Rol                  706 non-null    object
#  3   Victima              708 non-null    object
#  4   Sexo                 711 non-null    object
#  5   Edad                 664 non-null    float64
#  6   Fecha_fallecimiento  649 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 39.3+ KB

# %% [markdown]
# Vemos que si tenemos nulos

# %% [markdown]
# ## Merge

# %%
merge = pd.merge(left=hechos, right=victimas,on='Id_hecho', how='inner') # Hacemos un merge entero

# %%
merge.head(1) # Vemos un registro ejemplo
# Out:
#     Id_hecho  Victimas    Fecha_x  Hora Tipo_calle  \
# 0  2016-0001         1 2016-01-01     4    avenida
#
#                                  Cruce  \
# 0  Fernandez de la cruz, f., gral. av.
#
#                                            Direccion  Comuna  Longitud  \
# 0  Piedra buena av. y fernandez de la cruz, f., g...       8 -58.47534
#
#     Latitud Tipo_victima Tipo_acusado    Fecha_y        Rol Victima  \
# 0 -34.68757         moto         auto 2016-01-01  conductor    moto
#
#         Sexo  Edad Fecha_fallecimiento
# 0  masculino  19.0          2016-01-01

# %% [markdown]
# Vemos que al hacer el merge, no se joinea la columna fecha, y se crean dos diferentes, eso se debe a q tienen valores diferentes, analicemoslas.

# %%
x = merge.Fecha_x.tolist() # Extraigo las fechas de la primera columna
y = merge.Fecha_y.tolist() # Extraigo las fechas de la segunda columna
for i in range(len(x)): # Por cada fecha
    if x[i] == y[i]: # Si las fechas coinciden
        pass 
    else:
        print('Fecha_hechos: ',x[i],'Fecha_victimas: ',y[i], i) # Si no coincide, muestro las diferencias
# Out:
# Fecha_hechos:  2016-07-02 00:00:00 Fecha_victimas:  2016-07-03 00:00:00 65
# Fecha_hechos:  2017-05-24 00:00:00 Fecha_victimas:  2017-05-29 00:00:00 204

# %% [markdown]
# Tenemos dos fechas diferentes asi que las imputo manualmente a un valor de los dos.

# %%
merge.loc[merge['Fecha_x'] == '2016-07-02 00:00:00', 'Fecha_x'] = '2016-07-03 00:00:00'
merge.loc[merge['Fecha_x'] == '2017-05-24 00:00:00', 'Fecha_x'] = '2017-05-29 00:00:00'
# Cambio las fechas a las de la otra
merge.drop('Fecha_y',axis=1,inplace=True) # Y elimino la fecha 'y'
merge.rename(columns={'Fecha_x':'Fecha'}, inplace=True) # Y cambiamos el nombre de la 'x'

# %%
for col in victimas.columns.tolist():
    print(col,":",victimas[col].duplicated().unique())
# Out:
# Id_hecho : [False  True]
# Fecha : [False  True]
# Rol : [False  True]
# Victima : [False  True]
# Sexo : [False  True]
# Edad : [False  True]
# Fecha_fallecimiento : [False  True]

# %% [markdown]
# uhh problemitas, no puede haber ids duplicados.

# %%
victimas[victimas['Id_hecho'].duplicated()]
# Out:
#       Id_hecho      Fecha                   Rol Victima       Sexo  Edad  \
# 30   2016-0041 2016-03-29  pasajero_acompañante    moto  masculino   NaN
# 99   2016-0126 2016-09-18  pasajero_acompañante    auto  masculino  60.0
# 164  2017-0026 2017-02-26             conductor    auto  masculino  19.0
# 174  2017-0035 2017-03-23  pasajero_acompañante    auto  masculino  32.0
# 175  2017-0035 2017-03-23  pasajero_acompañante    auto  masculino  30.0
# 177  2017-0036 2017-03-29             conductor    moto  masculino  20.0
# 187  2017-0050 2017-04-28  pasajero_acompañante    moto  masculino  16.0
# 238  2017-0108 2017-09-02  pasajero_acompañante    auto  masculino  10.0
# 243  2017-0112 2017-09-10  pasajero_acompañante    auto  masculino   NaN
# 254  2017-0126 2017-10-14             conductor    auto  masculino  36.0
# 278  2017-0153 2017-12-11             conductor    moto  masculino  30.0
# 301  2018-0015 2018-02-06  pasajero_acompañante    moto  masculino  19.0
# 313  2018-0026 2018-03-09  pasajero_acompañante   movil  masculino  30.0
# 326  2018-0038 2018-04-20                peaton  peaton  masculino  61.0
# 374  2018-0085 2018-08-03             conductor    moto  masculino  30.0
# 388  2018-0098 2018-09-09  pasajero_acompañante    auto  masculino  54.0
# 419  2018-0128 2018-11-25  pasajero_acompañante    auto   femenino  39.0
# 445  2019-0010 2019-02-02                peaton  peaton  masculino  59.0
# 577  2020-0038 2020-08-30             conductor    auto  masculino  64.0
# 603  2020-0063 2020-12-05  pasajero_acompañante    moto  masculino  21.0
# 617  2020-0077 2020-12-25  pasajero_acompañante    moto   femenino  24.0
#
#     Fecha_fallecimiento
# 30           2016-03-30
# 99                  NaT
# 164          2017-02-26
# 174          2017-03-23
# 175          2017-03-23
# 177          2017-03-29
# 187          2017-04-28
# 238          2017-09-02
# 243          2017-09-13
# 254          2017-10-14
# 278          2017-12-12
# 301          2018-02-06
# 313          2018-03-09
# 326          2018-04-20
# 374          2018-08-03
# 388          2018-09-09
# 419          2018-11-25
# 445          2019-02-02
# 577          2020-08-30
# 603          2020-12-05
# 617          2020-12-25

# %% [markdown]
# Vemos que el id no es un duplicado realmente. Lo que sucede es que los primeros numeros son iguales entonces los toma como duplicados aunque no lo sean realmente.

# %% [markdown]
# Tenemos nuestros datasets sin duplicados y nuestro merge tambien.

# %%
# Reseteamos indices
hechos.reset_index(drop=True, inplace=True)
victimas.reset_index(drop=True, inplace=True)
merge.reset_index(drop=True, inplace=True)

# %%
merge.drop('Victima',axis=1,inplace=True) #  Eliminamos la columna Victima

# %% [markdown]
# Exportamos cada archivo como .csv

# %%
victimas.to_csv('../Data/victimas.csv', index=False)
hechos.to_csv('../Data/hechos.csv', index=False)
merge.to_csv('../Data/merge.csv', index=False)
